# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/Nugget002_AD_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
users = [
    {"name":"Alice","department":"IT","enabled":True},
    {"name":"Bob","department":"IT","enabled":False},
    {"name":"Carol","department":"HR","enabled":True},
    {"name":"David","department":"Finance","enabled":True}
]

print(f"Total Users: {len(users)}")
# Out:
# Total Users: 4

# %%
enabled_count = sum(1 for u in users if u["enabled"])

print(f"Enabled Users: {enabled_count}")
# Out:
# Enabled Users: 3

# %%
departments = {}

for user in users:
  dept = user["department"]
  departments[dept] = departments.get(dept,0)+1

print(departments)
# Out:
# {'IT': 2, 'HR': 1, 'Finance': 1}
