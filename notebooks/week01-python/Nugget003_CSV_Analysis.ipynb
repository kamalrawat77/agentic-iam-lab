# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/week01-python/Nugget003_CSV_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("users.csv")

print(df)

# %%
print("Total Users:", len(df))

# %%
print(df["department"].value_counts())

# %%
enabled_users = df[df["enabled"] == True]

print("Enabled Users:", len(enabled_users))

# %%
print(enabled_users)
