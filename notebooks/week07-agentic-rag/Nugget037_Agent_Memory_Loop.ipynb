# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/week07-agentic-rag/Nugget037_Agent_Memory_Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nugget 037: Agent Memory Loop (ReAct Fundamentals)

# %%
# !pip install -q google-genai
import json

# %%
from google import genai

def callGPT(prompt):
  client = genai.Client(api_key="APIKEY")
  response = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=prompt
  )

  return response

# %% [markdown]
# Tool List

# %%
def dormant_accounts():

    return "Dormant Accounts: 27"


def department_breakdown():

    return """
IT: 45
HR: 12
Finance: 18
"""


def search_history():

    return """
Past Investigation:
Inactive Approvers
"""


def trend_analysis():

    return """
Dormant Accounts:
20 → 25 → 27
Increasing Trend
"""

# %% [markdown]
# Create memory list

# %%
memory = []

# %%
question = """
Why are dormant accounts increasing?
"""

# %%
trend_result = trend_analysis()

# %%
memory.append({
    "tool":"trend_analysis",
    "observation":trend_result
})

# %%
print(memory)
# Out:
# [{'tool': 'trend_analysis', 'observation': '\nDormant Accounts:\n20 → 25 → 27\nIncreasing Trend\n'}]

# %%
history_result = search_history()

# %%
memory.append({
    "tool":"search_history",
    "observation":history_result
})

# %%
for item in memory:
    print(item)
# Out:
# {'tool': 'trend_analysis', 'observation': '\nDormant Accounts:\n20 → 25 → 27\nIncreasing Trend\n'}
# {'tool': 'search_history', 'observation': '\nPast Investigation:\nInactive Approvers\n'}

# %%
prompt = f"""
You are an IAM investigator.

Question:

{question}

Investigation Memory:

{memory}

Based on the observations,
provide:

1. Root Cause
2. Confidence
3. Recommendation
"""

# %%
print(callGPT(prompt).text)
# Out:
# Here's the investigation report:
#
# ### 1. Root Cause
#
# The increasing trend in dormant accounts is primarily caused by **stalled account lifecycle management processes, specifically the deactivation phase, due to inactive or unresponsive approvers.** Accounts are being identified as dormant, but the subsequent approval workflow required for their deactivation is experiencing significant bottlenecks, leading to a backlog and accumulation of these accounts. Ineffective offboarding procedures may also contribute by failing to proactively deprovision accounts before they become dormant.
#
# ### 2. Confidence
#
# **High.** The explicit observation of "Inactive Approvers" from a past investigation directly correlates with the increase in dormant accounts, indicating a critical breakdown in the deactivation process. While other factors might contribute, this is a clear and direct actionable cause.
#
# ### 3. Recommendation
#
# 1.  **Address Inactive Approvers Immediately:**
# ...
