# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/notebooks/week10-LangGraph/Agentic_IAM_LangGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kamalrawat77/agentic-iam-lab.git

# %cd agentic-iam-lab
# Out:
# Cloning into 'agentic-iam-lab'...
# remote: Enumerating objects: 855, done.
# remote: Counting objects: 100% (317/317), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 855 (delta 190), reused 189 (delta 95), pack-reused 538 (from 1)
# Receiving objects: 100% (855/855), 377.03 KiB | 13.00 MiB/s, done.
# Resolving deltas: 100% (502/502), done.
# /content/agentic-iam-lab

# %%
from scripts.bootstrap import bootstrap

bootstrap()
# Out:
# ============================================================
# Agentic IAM Lab Bootstrap
# ============================================================
# ✓ Git configured
# ✓ Secrets loaded
# ✓ Bootstrap complete

# %%
from scripts.bootstrap import (push,pull)

push("Bootstrap updated 1")
# Out:
# ============================================================
# Agentic IAM Lab Push
# ============================================================
# ✓ Git Pushed
# ============================================================
# [CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr=''), CompletedProcess(args=['git', 'commit', '-m', 'Bootstrap updated 1'], returncode=0, stdout='[main 158030d] Bootstrap updated 1\n 1 file changed, 1 insertion(+), 1 deletion(-)\n', stderr=''), CompletedProcess(args=['git', 'push'], returncode=0, stdout='', stderr='To https://github.com/kamalrawat77/agentic-iam-lab.git\n   f9ca3a1..158030d  main -> main\n')]
# ✓ [CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr=''), CompletedProcess(args=['git', 'commit', '-m', 'Bootstrap updated 1'], returncode=0, stdout='[main 158030d] Bootstrap updated 1\n 1 file changed, 1 insertion(+), 1 deletion(-)\n', stderr=''), CompletedProcess(args=['git', 'push'], returncode=0, stdout='', stderr='To https://github.com/kamalrawat77/agentic-iam-lab.git\n   f9ca3a1..158030d  main -> main\n')]
# ============================================================

# %%
import importlib
import scripts.graph.workflow
#import scripts.graph.nodes
#importlib.reload(scripts.graph.nodes)
importlib.reload(scripts.graph.workflow)
# Out:
# <module 'scripts.graph.workflow' from '/content/agentic-iam-lab/scripts/graph/workflow.py'>

# %%
pull()
# Out:
# ============================================================
# Agentic IAM Lab Pull
# ============================================================
# ✓ Git Pulled
# ============================================================
# ✓ CompletedProcess(args=['git', 'pull'], returncode=0, stdout='Already up to date.\n', stderr='')
# ✓ Already up to date.
#
# ============================================================

# %% [markdown]
# 🚀 Nugget 059 — Your First LangGraph Agent

# %%
# !pip install -q langgraph langchain langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 1.3 MB/s eta 0:00:00

# %%
from scripts.graph.workflow import graph

from scripts.core.investigation import Investigation

investigation = Investigation(
    question="Find dormant accounts"
)

state = {

    "investigation": investigation
}

result = graph.invoke(state)
# Out:
# Decorator executed for dormant_accounts
# Registered dormant_accounts
# Decorator executed for department_breakdown
# Registered department_breakdown
# Executing: dormant_accounts
# Completed: dormant_accounts

# %%
print(result["investigation"].status)
print(result["investigation"].results)
# Out:
# COMPLETED
# [[{'tool': 'dormant_accounts', 'purpose': 'Identify all user accounts that have not been active for a significant period to determine their current status and necessity.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]]

# %%
for event in graph.stream(state):

    print(event)
# Out:
# {'planner': {'investigation': Investigation(question='Find dormant accounts', plan=Plan(goal='Find dormant user accounts across the system to identify potential security risks or clean-up opportunities.', steps=[PlanStep(tool='dormant_accounts', purpose='Identify user accounts that have not been active for a specified period.', description='Find dormant accounts', arguments={})]), context=ExecutionContext(execution_id='026a3213-fa9b-4d39-be01-fcc906e20dd8', question='Find dormant accounts', tool_results={'dormant_accounts': {'count': 42, 'days': 90}}, metadata={}, errors=[]), status='PLANNED', results=[[{'tool': 'dormant_accounts', 'purpose': 'Identify all user accounts that have not been active for a significant period to determine their current status and necessity.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]], errors=[])}}
# Executing: dormant_accounts
# Completed: dormant_accounts
# {'executor': {'investigation': Investigation(question='Find dormant accounts', plan=Plan(goal='Find dormant user accounts across the system to identify potential security risks or clean-up opportunities.', steps=[PlanStep(tool='dormant_accounts', purpose='Identify user accounts that have not been active for a specified period.', description='Find dormant accounts', arguments={})]), context=ExecutionContext(execution_id='ec3c07d8-4d58-426f-a53f-1cfb75e2cf03', question='Find dormant accounts', tool_results={'dormant_accounts': {'count': 42, 'days': 90}}, metadata={}, errors=[]), status='COMPLETED', results=[[{'tool': 'dormant_accounts', 'purpose': 'Identify all user accounts that have not been active for a significant period to determine their current status and necessity.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}], [{'tool': 'dormant_accounts', 'purpose': 'Identify user accounts that have not been active for a specified period.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]], errors=[])}}

# %%
from scripts.bootstrap import (push,pull)

push("Nugget 059 - First LangGraph workflow")
# Out:
# ============================================================
# Agentic IAM Lab Push
# ============================================================
# ✓ Git Pushed
# ============================================================
# [CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr=''), CompletedProcess(args=['git', 'commit', '-m', 'Nugget 059 - First LangGraph workflow'], returncode=0, stdout='[main bf7302f] Nugget 059 - First LangGraph workflow\n 2 files changed, 2 insertions(+)\n create mode 100644 notebooks/week09-AgenticModel/README.md\n create mode 100644 notebooks/week10-LangGraph/README.md\n', stderr=''), CompletedProcess(args=['git', 'push'], returncode=0, stdout='', stderr='To https://github.com/kamalrawat77/agentic-iam-lab.git\n   af85d06..bf7302f  main -> main\n')]
# ============================================================

# %%
pull()
# Out:
# ============================================================
# Agentic IAM Lab Pull
# ============================================================
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_2141/807495298.py in <cell line: 0>()
# ----> 1 pull()
#
# /content/agentic-iam-lab/scripts/bootstrap.py in pull()
#     104   print("=" * 60)
#     105
# --> 106   result=subprocess.run(
#     107         [
#     108             "git",
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569         retcode = process.poll()
#     570         if check and retcode:
# --> 571             raise CalledProcessError(retcode, process.args,
#     572                                      output=stdout, stderr=stderr)
#     573     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['git', 'pull']' returned non-zero exit status 128.

# %% [markdown]
# 🚀 Nugget 059 - Container infrastructure

# %%
from scripts.infrastructure.bootstrap import (
    initialize,
    container
)
from scripts.core.investigation import Investigation

initialize()

investigation = Investigation(
    question="Find dormant accounts"
)

result = container.graph.invoke(
    {
        "investigation": investigation
    }
)

# %%
print(result["investigation"].status)
print(result["investigation"].results)
# Out:
# COMPLETED
# [[{'tool': 'dormant_accounts', 'purpose': 'Identify accounts that have been inactive for a specified period, starting with the default inactivity threshold.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]]

# %%
from scripts.bootstrap import (push,pull)

push("Nugget 060 - Add composition root and dependency container")

# %% [markdown]
# 🚀 Nugget 061 - App as container

# %%
from scripts.application.app import app
from scripts.core.investigation import Investigation

app.initialize()

investigation = Investigation(
    question="Find dormant accounts"
)

result = app.graph.invoke(
    {
        "investigation": investigation
    }
)

print(result["investigation"].status)
print(result["investigation"].results)
# Out:
# Executing: dormant_accounts
# Completed: dormant_accounts
# COMPLETED
# [[{'tool': 'dormant_accounts', 'purpose': 'Find all accounts that have been dormant for the default period (90 days).', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]]

# %%
from scripts.bootstrap import (push,pull)

push("Nugget 061 - Introduce Application as composition root")
# Out:
# ============================================================
# Agentic IAM Lab Push
# ============================================================
# ✓ Git Pushed
# ============================================================
# [CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr=''), CompletedProcess(args=['git', 'commit', '-m', 'Nugget 061 - Introduce Application as composition root'], returncode=0, stdout='[main b95c490] Nugget 061 - Introduce Application as composition root\n 3 files changed, 189 insertions(+), 1 deletion(-)\n create mode 100644 docs/learning_logs/Nugget_060.md\n create mode 100644 docs/learning_logs/Nugget_061.md\n', stderr=''), CompletedProcess(args=['git', 'push'], returncode=0, stdout='', stderr='To https://github.com/kamalrawat77/agentic-iam-lab.git\n   b4eeccd..b95c490  main -> main\n')]
# ============================================================

# %% [markdown]
# 🚀 Nugget 062 — State is Everything

# %%
from scripts.application.app import app
from scripts.core.investigation import Investigation

app.initialize()

investigation = Investigation(
    question="Find dormant accounts"
)

result = app.graph.invoke(
    {
        "investigation": investigation
    }
)

print(result["investigation"].status)
print(result["investigation"].results)
# Out:
# Decorator executed for dormant_accounts
# Registered dormant_accounts
# Decorator executed for department_breakdown
# Registered department_breakdown
# Executing: dormant_accounts
# Completed: dormant_accounts
# InvestigationStatus.COMPLETED
# [[{'tool': 'dormant_accounts', 'purpose': 'Identify accounts that have not been active for a specified period.', 'status': 'SUCCESS', 'result': {'count': 42, 'days': 90}, 'execution_time': 0.0}]]

# %%
from scripts.bootstrap import (push,pull)

push("Nugget 062 - Refactor Investigation into workflow state")
# Out:
# ============================================================
# Agentic IAM Lab Push
# ============================================================
# ✓ Git Pushed
# ============================================================
# [CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr=''), CompletedProcess(args=['git', 'commit', '-m', 'Nugget 062 - Refactor Investigation into workflow state'], returncode=0, stdout='[main f0eb410] Nugget 062 - Refactor Investigation into workflow state\n 4 files changed, 20 insertions(+), 4 deletions(-)\n create mode 100644 scripts/core/status.py\n', stderr=''), CompletedProcess(args=['git', 'push'], returncode=0, stdout='', stderr='To https://github.com/kamalrawat77/agentic-iam-lab.git\n   b95c490..f0eb410  main -> main\n')]
# ============================================================
