# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/week05-investigation-agents/Nugget026_Persistent_Memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nugget 026: Persistent Investigation Memory

# %%
# !pip install -q google-genai

# %%
from google import genai

def callGPT(prompt):
  client = genai.Client(api_key="APIKEY")
  response = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=prompt
  )

  return response

# %%
def cleanse_response(response):
  clean_response=clean_response = response.text
  clean_response = clean_response.replace("```json", "")
  clean_response = clean_response.replace("```", "")
  clean_response = clean_response.strip()

  return clean_response

# %%
import json

def return_json(clean_response,objname):
  responseObj = json.loads(clean_response)
  resJsonObj  = responseObj[objname]
  return resJsonObj

# %% [markdown]
# Create investigation history

# %%
investigation_history = []

# %%
investigation = {
    "date": "2026-06-22",
    "dormant_accounts": 70,
    "inactive_approvers": 35,
    "sla_compliance": 72
}

# %%
investigation_history.append(investigation)

print(investigation_history)
# Out:
# [{'date': '2026-06-22', 'dormant_accounts': 70, 'inactive_approvers': 35, 'sla_compliance': 72}]

# %%
def save_investigation(memory, investigation):

    memory.append(investigation)

    return memory

# %%
def get_last_investigation(memory):

    if len(memory) == 0:
        return None

    return memory[-1]

# %%
print(get_last_investigation(investigation_history))
# Out:
# {'date': '2026-06-22', 'dormant_accounts': 75, 'inactive_approvers': 25, 'sla_compliance': 70}

# %%
investigation = {
    "date": "2026-06-22",
    "dormant_accounts": 75,
    "inactive_approvers": 25,
    "sla_compliance": 70
}

save_investigation(investigation_history, investigation)
# Out:
# [{'date': '2026-06-22',
#   'dormant_accounts': 70,
#   'inactive_approvers': 35,
#   'sla_compliance': 72},
#  {'date': '2026-06-22',
#   'dormant_accounts': 75,
#   'inactive_approvers': 25,
#   'sla_compliance': 70}]

# %%
current = investigation_history[-1]

previous = investigation_history[-2]

# %%
prompt = f"""
Previous Investigation:

{previous}

Current Investigation:

{current}

Compare the investigations.

Identify:

1. Improvements
2. Worsening Risks
3. Emerging Trends
"""

# %%
print(callGPT(prompt).text)
# Out:
# Here's a comparison of the investigations:
#
# **Comparison Overview:**
# The investigations, both conducted on the same date, reveal a mixed performance, with improvements in one area offset by worsening risks in others.
#
# ---
#
# 1.  **Improvements:**
#     *   **Inactive Approvers:** Decreased from **35** to **25** (a reduction of 10). This is a positive development, indicating a more engaged or streamlined approval process, which can reduce bottlenecks and improve workflow efficiency.
#
# 2.  **Worsening Risks:**
#     *   **Dormant Accounts:** Increased from **70** to **75** (an increase of 5). This is a worsening risk, as dormant accounts can pose security vulnerabilities (e.g., unmonitored access points) and indicate a lack of proper account lifecycle management.
# ...

# %%
import json

with open("investigation_memory.json", "w") as f:
    json.dump(investigation_history, f)

# %%
with open("investigation_memory.json") as f:
    memory = json.load(f)
