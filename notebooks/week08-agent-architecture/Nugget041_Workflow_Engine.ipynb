# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/week08-agent-architecture/Nugget041_Workflow_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nugget 041: Build a LangGraph-Style Workflow Engine

# %% [markdown]
# Create graph.

# %%
workflow = {
    "PLAN": "RETRIEVE",
    "RETRIEVE": "ANALYZE",
    "ANALYZE": "DECIDE",
    "DECIDE": "FINISH"
}

# %% [markdown]
# Initial state:

# %%
current_state = "PLAN"

# %% [markdown]
# Create node functions.

# %%
def plan(state):

    print("Planning")
    print(state)
    return state


def retrieve(state):

    print("Retrieving")
    print(state)
    state["evidence"].append(
        "Dormant accounts increasing"
    )

    return state


def analyze(state):

    print("Analyzing")
    print(state)
    state["analysis"] = (
        "Likely JML backlog"
    )

    return state


def decide(state):

    print("Decision Complete")
    print(state)
    return state

# %% [markdown]
# Create node registry.

# %%
nodes = {
    "PLAN": plan,
    "RETRIEVE": retrieve,
    "ANALYZE": analyze,
    "DECIDE": decide
}

# %% [markdown]
# Shared state:

# %%
agent_state = {
    "question":
        "Why are dormant accounts increasing?",
    "evidence": [],
    "analysis": None
}

# %% [markdown]
# Execute graph.

# %%
while current_state != "FINISH":

    node = nodes[current_state]

    agent_state = node(agent_state)

    current_state = workflow[current_state]
# Out:
# Planning
# {'question': 'Why are dormant accounts increasing?', 'evidence': [], 'analysis': None}
# Retrieving
# {'question': 'Why are dormant accounts increasing?', 'evidence': [], 'analysis': None}
# Analyzing
# {'question': 'Why are dormant accounts increasing?', 'evidence': ['Dormant accounts increasing'], 'analysis': None}
# Decision Complete
# {'question': 'Why are dormant accounts increasing?', 'evidence': ['Dormant accounts increasing'], 'analysis': 'Likely JML backlog'}

# %%
print(agent_state)
# Out:
# {'question': 'Why are dormant accounts increasing?', 'evidence': ['Dormant accounts increasing'], 'analysis': 'Likely JML backlog'}
