# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/notebooks/week08-investigation-agent/Nugget046_BootstrapSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nugget 046 — Build the Bootstrap System

# %%
# !git clone https://github.com/kamalrawat77/agentic-iam-lab.git

# %cd agentic-iam-lab

#!pip install -r requirements.txt
# Out:
# Cloning into 'agentic-iam-lab'...
# remote: Enumerating objects: 628, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 628 (delta 66), reused 52 (delta 46), pack-reused 538 (from 1)
# Receiving objects: 100% (628/628), 262.74 KiB | 15.46 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# /content/agentic-iam-lab

# %%
from scripts.bootstrap import bootstrap

bootstrap()
# Out:
# ...
# Agentic IAM Lab Bootstrap
# ...
# ✓ Git configured
# ✓ Secrets loaded
# ✓ Bootstrap complete

# %%
# !git remote -v

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !git add .
# !git commit -m "Nugget 046 - Add bootstrap module"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
