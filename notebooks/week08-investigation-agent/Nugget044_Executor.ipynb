# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalrawat77/agentic-iam-lab/blob/main/notebooks/week08-investigation-agent/Nugget044_Executor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nugget 044: Build the Investigation Executor

# %%
# !git clone https://github.com/kamalrawat77/agentic-iam-lab.git

# %cd agentic-iam-lab

#!pip install -r requirements.txt
# Out:
# Cloning into 'agentic-iam-lab'...
# remote: Enumerating objects: 595, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 595 (delta 53), reused 43 (delta 43), pack-reused 537 (from 1)
# Receiving objects: 100% (595/595), 249.96 KiB | 6.25 MiB/s, done.
# Resolving deltas: 100% (365/365), done.
# /content/agentic-iam-lab/agentic-iam-lab

# %%
import scripts.agent.executor as executor
import scripts.agent.planner as planner

# %%
question = """
Why are dormant accounts increasing?
"""

# %%
available_tools=[
    "trend_analysis",
    "search_history",
    "dormant_accounts"
]

# %%
plan = planner.Planner().create_plan(question,available_tools)

# %%
print(plan)
# Out:
# {'investigation': 'To determine the root causes behind the increasing number of dormant accounts by analyzing historical trends, examining account specifics, and reviewing related policy and process changes.', 'steps': [{'tool': 'trend_analysis', 'purpose': 'To quantify the rate of increase in dormant accounts over specific periods (e.g., last 3, 6, 12 months). Identify any spikes, correlations with organizational events (e.g., acquisitions, major project rollouts/closures), or specific account types (e.g., user accounts vs. service accounts, contractor accounts) or departments showing a higher dormancy rate.'}, {'tool': 'dormant_accounts', 'purpose': 'To retrieve detailed information on a significant sample of recently dormant accounts. This includes their creation date, last activity date, associated owner/department, linked applications/systems, and account type (user, service, contractor, vendor). This will help identify common characteristics or attributes among the increasing d
# ...

# %%
evidence = executor.Executor().execute(plan)
# Out:
# Executing: trend_analysis
# Completed: trend_analysis
# Executing: dormant_accounts
# Completed: dormant_accounts
# Executing: search_history
# Completed: search_history

# %%
print(evidence)
# Out:
# [{'tool': 'trend_analysis', 'purpose': 'To quantify the rate of increase in dormant accounts over specific periods (e.g., last 3, 6, 12 months). Identify any spikes, correlations with organizational events (e.g., acquisitions, major project rollouts/closures), or specific account types (e.g., user accounts vs. service accounts, contractor accounts) or departments showing a higher dormancy rate.', 'status': 'SUCCESS', 'result': 'Dormant accounts increased from 20 to 27', 'execution_time': 0.0}, {'tool': 'dormant_accounts', 'purpose': 'To retrieve detailed information on a significant sample of recently dormant accounts. This includes their creation date, last activity date, associated owner/department, linked applications/systems, and account type (user, service, contractor, vendor). This will help identify common characteristics or attributes among the increasing dormant accounts.', 'status': 'SUCCESS', 'result': 'Dormant Accounts: 27', 'execution_time': 0.0}, {'tool': 'search_histor
# ...
